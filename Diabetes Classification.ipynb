# %%
# Importing necessary libraries
import pandas as pd


# Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset file
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import pandas as pd
from pycaret.classification import setup, compare_models, create_model, tune_model, predict_model
import pycaret

# Print PyCaret version
print(pycaret.__version__)

# ✅ Load your dataset (make sure the file path is correct)
df = pd.read_csv('diabetes.csv')  # 🔁 Replace 'your_file.csv' with your actual CSV filename

# ✅ Run PyCaret setup
clf_setup = setup(
    data=df,
    target='Outcome',           # 🔁 Replace 'Outcome' with the correct target column if needed
    session_id=42,              # For reproducibility
    normalize=True,             # Scale and normalize data
    remove_outliers=True,       # Remove extreme outliers
    feature_selection=True,     # Enable automatic feature selection
    train_size=0.8              # 80% training, 20% testing split
)
# Out:
# 3.3.2
# <style type="text/css">
# #T_53cbf_row8_col1, #T_53cbf_row12_col1, #T_53cbf_row14_col1, #T_53cbf_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_53cbf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53cbf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_53cbf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53cbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53cbf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_53cbf_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_53cbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53cbf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_53cbf_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
# ...

# %%
# Step 4: Train and Compare Multiple Models
# This trains and compares all classification models available in PyCaret
best_model = compare_models()

# Step 5: Display the Best Model
print("Best Model Identified by PyCaret:")
print(best_model)
# Out:
# <style type="text/css">
# #T_4fc58 th {
#   text-align: left;
# }
# ...
